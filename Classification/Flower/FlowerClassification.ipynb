# %% [markdown]
# # Image classification (5 class of flowers: Tulips, Roses, Daisy, Dandelion, Sunflowers)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pathlib
import urllib.request

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x272 at 0x7F5ABE022CD0>

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7F5ABD838D90>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F5ABD838A60>

# %%
PIL.Image.open(str(tulips[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F5ABD838E50>

# %% [markdown]
# ## Create a dataset

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, validation_split = 0.2, subset="training",
    seed = 123, image_size=(img_height,img_width),
    batch_size = batch_size)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, validation_split = 0.2, subset="validation",
    seed = 123, image_size=(img_height,img_width),
    batch_size = batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %% [markdown]
# ## Visualize the data

# %%
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x),y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0024510254 0.99846584

# %% [markdown]
# ## Data augmentation

# %%
data_augmentation = tf.keras.models.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",input_shape=(img_height,img_width,3)),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
plt.figure(figsize=(10,10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3,3,i+1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ## Build and train the model with augmented data

# %%
num_classes = 5

model = tf.keras.models.Sequential([
    data_augmentation,
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D(16,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(128,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(256,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3277312
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 3,672,485
# Trainable params: 3,672,485
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 30
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/30
# 92/92 [==============================] - 7s 49ms/step - loss: 1.2892 - accuracy: 0.4278 - val_loss: 1.1346 - val_accuracy: 0.5095
# Epoch 2/30
# 92/92 [==============================] - 3s 37ms/step - loss: 1.0391 - accuracy: 0.5746 - val_loss: 0.9780 - val_accuracy: 0.5995
# Epoch 3/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.9584 - accuracy: 0.6076 - val_loss: 0.8911 - val_accuracy: 0.6553
# Epoch 4/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.8737 - accuracy: 0.6482 - val_loss: 0.9903 - val_accuracy: 0.5926
# Epoch 5/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.8380 - accuracy: 0.6649 - val_loss: 0.8362 - val_accuracy: 0.6649
# Epoch 6/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.7985 - accuracy: 0.6839 - val_loss: 0.7733 - val_accuracy: 0.6757
# Epoch 7/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.7623 - accuracy: 0.6989 - val_loss: 0.7695 - val_accuracy: 0.6853
# Epoch 8/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.7499 - accuracy: 0.7050 - val_loss: 0.7153 - val_accuracy: 0.7057
# Epoch 9/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.7091 - accuracy: 0.7279 - val_loss: 0.7408 - val_accuracy: 0.6935
# Epoch 10/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.7211 - accuracy: 0.7221 - val_loss: 0.7943 - val_accuracy: 0.6921
# Epoch 11/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.6767 - accuracy: 0.7279 - val_loss: 0.7682 - val_accuracy: 0.7003
# Epoch 12/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.6743 - accuracy: 0.7381 - val_loss: 0.7566 - val_accuracy: 0.7016
# Epoch 13/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.6281 - accuracy: 0.7592 - val_loss: 0.8568 - val_accuracy: 0.6676
# Epoch 14/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.6430 - accuracy: 0.7449 - val_loss: 0.6839 - val_accuracy: 0.7166
# Epoch 15/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.6301 - accuracy: 0.7636 - val_loss: 0.7389 - val_accuracy: 0.7289
# Epoch 16/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.5888 - accuracy: 0.7715 - val_loss: 0.8447 - val_accuracy: 0.7030
# Epoch 17/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.5943 - accuracy: 0.7667 - val_loss: 0.6943 - val_accuracy: 0.7398
# Epoch 18/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.5745 - accuracy: 0.7800 - val_loss: 0.8279 - val_accuracy: 0.6880
# Epoch 19/30
# 92/92 [==============================] - 4s 38ms/step - loss: 0.5547 - accuracy: 0.7824 - val_loss: 0.6597 - val_accuracy: 0.7616
# Epoch 20/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.5519 - accuracy: 0.7820 - val_loss: 0.6696 - val_accuracy: 0.7480
# Epoch 21/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.5457 - accuracy: 0.7847 - val_loss: 0.7842 - val_accuracy: 0.7003
# Epoch 22/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.5288 - accuracy: 0.7980 - val_loss: 0.7805 - val_accuracy: 0.7139
# Epoch 23/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.4970 - accuracy: 0.8062 - val_loss: 0.7410 - val_accuracy: 0.7262
# Epoch 24/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.4898 - accuracy: 0.8110 - val_loss: 0.7058 - val_accuracy: 0.7520
# Epoch 25/30
# 92/92 [==============================] - 4s 38ms/step - loss: 0.4602 - accuracy: 0.8239 - val_loss: 0.7464 - val_accuracy: 0.7439
# Epoch 26/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.4597 - accuracy: 0.8249 - val_loss: 0.6947 - val_accuracy: 0.7602
# Epoch 27/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.4435 - accuracy: 0.8273 - val_loss: 0.6283 - val_accuracy: 0.7629
# Epoch 28/30
# 92/92 [==============================] - 4s 38ms/step - loss: 0.4274 - accuracy: 0.8277 - val_loss: 0.6862 - val_accuracy: 0.7616
# Epoch 29/30
# 92/92 [==============================] - 3s 38ms/step - loss: 0.4501 - accuracy: 0.8266 - val_loss: 0.6334 - val_accuracy: 0.7589
# Epoch 30/30
# 92/92 [==============================] - 4s 38ms/step - loss: 0.3997 - accuracy: 0.8491 - val_loss: 0.6332 - val_accuracy: 0.7643

# %% [markdown]
# ## Visualize training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,acc,label='Training Accuracy')
plt.plot(epochs_range,val_acc,label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,loss,label='Loss Accuracy')
plt.plot(epochs_range,val_loss,label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %% [markdown]
# ## Making some predictions

# %%
vector = {"tulip":"https://freepngimg.com/thumb/tulip/4-2-tulip-png-clipart.png",
          "daisy":"https://freepngimg.com/thumb/gerbera/27676-5-gerbera-transparent-background.png",
          "rose":"https://freepngimg.com/thumb/rose/1-rose-png-image-picture-download.png",
          "rose_2":"https://i.pinimg.com/originals/95/af/ff/95afff4bbe201992e64ea8ea28aad0bd.jpg",
          "daisy_2":"https://cdn2.stylecraze.com/wp-content/uploads/2013/11/Top-25-Most-Beautiful-Daisy-Flowers.jpg"}
print("\n")

for key,value in vector.items():
    path = tf.keras.utils.get_file(key,origin=value)
    img = tf.keras.preprocessing.image.load_img(path,target_size=(img_height,img_width))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array,0)
    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    
    im = PIL.Image.open(urllib.request.urlopen(value),'r')
    plt.imshow(im)
    plt.axis("off")
    plt.show()
    
    print("This image belongs to {} class with {:.2f} % of confidence.".format(class_names[np.argmax(score)],100*np.max(score)))
    print("\n")
# Out:
# This image belongs to tulips class with 99.67 % of confidence.
# This image belongs to daisy class with 99.67 % of confidence.
# This image belongs to roses class with 66.19 % of confidence.
# This image belongs to roses class with 99.72 % of confidence.
# This image belongs to daisy class with 99.81 % of confidence.
